# %%
import requests
import json

ur_generate = "http://localhost:11434/api/generate"

payload = {
    "model": "phi3",
    "prompt": "Explain how transformers work in 3 sentences.",
    "stream": False
}

response = requests.post(url, json=payload)

print(response.json()["response"])
# Out:
# Transformers are electrical devices that transfer energy between two or more circuits through electromagnetic induction, allowing for the increase or decrease of alternating current (AC) voltage levels with minimal loss during transmission and distribution processes while maintaining a constant frequency. They consist of two sets of coils called windings: primary and secondary, wrapped around a magnetic core; when AC power is applied to the primary winding, it generates an alternating magnetic field that induces an electric current in the nearby secondary winding without direct electrical connection between them due to Faraday'in law. By adjusting turns ratio of these windings—the number of coils on one relative to another—transformers can either step up or down voltage levels, which is critical for efficiently matching energy supply and demand across power grids while keeping safety standards intact by stepping voltages high enough at the source but lowered before consumption.

# %%
url_chat = "http://localhost:11434/api/chat"

payload = {
    "model": "phi3",
    "messages":[
        {"role": "system", "content": "Answer the user question with a short message with all capital letters"},
        {"role": "user", "content": "What does a strawberry taste like?"}
    ],
    "stream": False
}

response = requests.post(url_chat, json=payload)

print(response.json()["message"]["content"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 14
#       3 payload = {
#       4     "model": "phi3",
#       5     "messages":[
#    (...)
#       9     "stream": False
#      10 }
#      12 response = requests.post(url_chat, json=payload)
# ---> 14 print(response.json()["message"]["content"])
#
# KeyError: 'message'

# %%
INTENTS = {
    "recipe_request": ["recipe for", "how to cook", ...],
    "nutrition_request": ["how many calories", "nutrition info", ...],
    "shopping_request": ["add to shopping list", "buy", "purchase"],
}
